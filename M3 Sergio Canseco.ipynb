# %% [markdown]
# <a href="https://colab.research.google.com/github/CansecoSergio/python-data-science/blob/main/M3%20Sergio%20Canseco.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Reto Módulo 3 - Sergio Augusto Canseco Sánchez**

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', 10)

# %% [markdown]
#  **1.- Lectura de los archivos**

# %%
df_test1 = pd.read_csv('/content/drive/MyDrive/Archivos Collab/M3/Test.csv')
df_test2 = pd.read_csv('/content/drive/MyDrive/Archivos Collab/M3/Test2.csv')

df_train1 = pd.read_csv('/content/drive/MyDrive/Archivos Collab/M3/Train.csv')
df_train2 = pd.read_csv('/content/drive/MyDrive/Archivos Collab/M3/Train2.csv')

print('DF TEST 1')
df_test1.info()
print('---')
print('DF TEST 2')
df_test2.info()
print('---')
print('DF TRAIN 1')
df_train1.info()
print('---')
print('DF TRAIN 2')
df_train2.info()
# Out:
# DF TEST 1
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 23 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Employee_ID                3000 non-null   object
#  1   Gender                     3000 non-null   object
#  2   Age                        2839 non-null   float64
#  3   Education_Level            3000 non-null   int64
#  4   Relationship_Status        3000 non-null   object
#  5   Hometown                   3000 non-null   object
#  6   Unit                       3000 non-null   object
#  7   Decision_skill_possess     3000 non-null   object
#  8   Time_of_service            2948 non-null   float64
#  9   Time_since_promotion       3000 non-null   int64
#  10  growth_rate                3000 non-null   int64
#  11  Travel_Rate                3000 non-null   int64
#  12  Post_Level                 3000 non-null   int64
# ...

# %% [markdown]
# **2.- Unión de los datos para los archivos con la información de empleados.**

# %%
employees_df = pd.concat([df_test1, df_train1], ignore_index=True)
employees_df
# Out:
#      Employee_ID Gender   Age  Education_Level Relationship_Status  \
# 0      EID_22713      F  32.0                5              Single
# 1       EID_9658      M  65.0                2              Single
# 2      EID_22203      M  52.0                3             Married
# 3       EID_7652      M  50.0                5              Single
# 4       EID_6516      F  44.0                3             Married
# ...          ...    ...   ...              ...                 ...
# 9995   EID_16328      F  23.0                5             Married
# 9996    EID_8387      F  44.0                1             Married
# 9997    EID_8077      F  49.0                3              Single
# 9998   EID_19597      F  47.0                3             Married
# 9999    EID_1640      F  58.0                3             Married
#
#          Hometown        Unit Decision_skill_possess  Time_of_service  \
# 0     Springfield         R&D             Conceptual              7.0
# ...

# %% [markdown]
# **3.- Unión de los datos para los archivos con la información de tickets.**

# %%
tickets_df = pd.concat([df_test2, df_train2], ignore_index=True)
tickets_df.columns = tickets_df.columns.str.strip()
tickets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Employee_ID          10000 non-null  object
#  1   Computer_OS          9842 non-null   object
#  2   Computer_OS_version  9640 non-null   object
#  3   Computer_tickets     10000 non-null  int64
#  4   Mobile_OS            9713 non-null   object
#  5   Mobile_OS_version    9681 non-null   float64
#  6   Mobile_tickets       10000 non-null  int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 547.0+ KB

# %%
#count = employees_df[['Employee_ID']].groupby('Employee_ID').value_counts().reset_index(name='Count')
#max = count[['Count']].max()
#max
# Out:
# Count    1
# dtype: int64

# %% [markdown]
# **4.- Join de ambos dataframes (empleados y tickets).**

# %%
join_df = employees_df.merge(tickets_df, left_on='Employee_ID', right_on='Employee_ID', how='left')
#join_df[['Employee_ID', 'Computer_OS']]
join_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 30 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Employee_ID                10000 non-null  object
#  1   Gender                     10000 non-null  object
#  2   Age                        9427 non-null   float64
#  3   Education_Level            10000 non-null  int64
#  4   Relationship_Status        10000 non-null  object
#  5   Hometown                   10000 non-null  object
#  6   Unit                       10000 non-null  object
#  7   Decision_skill_possess     10000 non-null  object
#  8   Time_of_service            9804 non-null   float64
#  9   Time_since_promotion       10000 non-null  int64
#  10  growth_rate                10000 non-null  int64
#  11  Travel_Rate                10000 non-null  int64
#  12  Post_Level                 10000 non-null  int64
# ...

# %% [markdown]
# **5.- Asignación del valor "no registrado", para aquellos empleados que no hay registro de su sistema operativo.**

# %%
join_df.loc[pd.isna(join_df['Computer_OS']), ['Computer_OS']] = 'no registrado'
join_df.loc[pd.isna(join_df['Mobile_OS']), ['Mobile_OS']] = 'no registrado'
join_df[['Employee_ID', 'Computer_OS', 'Mobile_OS']]
# Out:
#      Employee_ID    Computer_OS Mobile_OS
# 0      EID_22713          MacOS       iOS
# 1       EID_9658        Windows   Android
# 2      EID_22203        Windows   Android
# 3       EID_7652        Windows       iOS
# 4       EID_6516        Windows   Android
# ...          ...            ...       ...
# 9995   EID_16328          MacOS       iOS
# 9996    EID_8387        Windows   Android
# 9997    EID_8077  no registrado       iOS
# 9998   EID_19597        Windows       iOS
# 9999    EID_1640          MacOS       iOS
#
# [10000 rows x 3 columns]

# %% [markdown]
# **A- El porcentaje de personas que usan "Windows/Mac/Linux/no registrado" como su sistema operativo en su computadora**

# %%
df_a = join_df[['Employee_ID', 'Computer_OS']]
df_a = join_df.groupby(by='Computer_OS').agg({'Computer_OS': np.size}).reset_index(names='SO').rename(columns={'Computer_OS': 'Total'})
df_a['Porcentaje'] = (df_a['Total'] * 100) / len(join_df.index)
df_a = df_a[['SO', 'Porcentaje']]
df_a
# Out:
#               SO  Porcentaje
# 0          Linux        4.80
# 1          MacOS       16.34
# 2        Windows       77.28
# 3  no registrado        1.58

# %% [markdown]
# **B- El porcentaje de personas que usan iOS / Android / No registrado como su sistema operativo en su dispositivo móvil**

# %%
df_b = join_df[['Employee_ID', 'Mobile_OS']]
df_b = join_df.groupby(by='Mobile_OS').agg({'Mobile_OS': np.size}).reset_index(names='SO').rename(columns={'Mobile_OS': 'Total'})
df_b['Porcentaje'] = (df_b['Total'] * 100) / len(join_df.index)
df_b = df_b[['SO', 'Porcentaje']]
df_b
# Out:
#               SO  Porcentaje
# 0        Android       76.59
# 1            iOS       20.54
# 2  no registrado        2.87

# %% [markdown]
# **C- La edad promedio de la gente que utiliza cada sistema operativo de escritorio**

# %%
df_c = join_df[['Employee_ID', 'Age', 'Computer_OS']]
df_c = join_df.groupby(by='Computer_OS').agg({'Age': np.mean}).reset_index(names='SO').rename(columns={'Age': 'Edad_Promedio'})
df_c['Edad_Promedio'] = round(df_c['Edad_Promedio'], 2)
df_c
# Out:
#               SO  Edad_Promedio
# 0          Linux          40.45
# 1          MacOS          40.40
# 2        Windows          39.46
# 3  no registrado          40.52

# %% [markdown]
# **D- El nivel educativo promedio de la gente que utiliza cada sistema operativo de escritorio**

# %%
df_d = join_df[['Employee_ID', 'Education_Level', 'Computer_OS']]
df_d = join_df.groupby(by='Computer_OS').agg({'Education_Level': np.mean}).reset_index(names='SO').rename(columns={'Education_Level': 'Nivel_Educativo_Promedio'})
df_d['Nivel_Educativo_Promedio'] = round(df_d['Nivel_Educativo_Promedio'])
df_d
# Out:
#               SO  Nivel_Educativo_Promedio
# 0          Linux                       3.0
# 1          MacOS                       3.0
# 2        Windows                       3.0
# 3  no registrado                       3.0

# %% [markdown]
# **E- El número total de tickets generados por la gente con cada sistema operativo de escritorio**

# %%
df_e = join_df[['Employee_ID', 'Computer_tickets', 'Computer_OS']]
df_e = join_df.groupby(by='Computer_OS').agg({'Computer_tickets': np.sum}).reset_index(names='SO').rename(columns={'Computer_tickets': 'Total_TIckets'})
df_e
# Out:
#               SO  Total_TIckets
# 0          Linux            254
# 1          MacOS           1880
# 2        Windows          21169
# 3  no registrado            541

# %% [markdown]
# **6.- Almacenamiento archivo Excel**

# %%
with pd.ExcelWriter('/content/drive/MyDrive/Archivos Collab/M3/resultados.xlsx') as writer:
    df_a.to_excel(writer, sheet_name='Ej A')
    df_b.to_excel(writer, sheet_name='Ej B')
    df_c.to_excel(writer, sheet_name='Ej C')
    df_d.to_excel(writer, sheet_name='Ej D')
    df_e.to_excel(writer, sheet_name='Ej E')
